# %% [markdown]
# # Linear Regression
#
#
# 1 - finds a pattern in old data
# 2 - straight line
# 3 - line
#
# y = mx + b

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

X = [[1],[2],[3],[4],[5]]
y = [40,50,65,75,90]


model.fit(X,y)
hours = float(input("Enter how many hours you studied"))

predicted_marks = model.predict([[hours]])

print(f"Based on your hours of study {hours} you scored {predicted_marks}")
# Out:
# Based on your hours of study 5.9 you scored [100.25]
